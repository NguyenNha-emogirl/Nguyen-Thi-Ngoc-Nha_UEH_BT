# %%
#1.Write a program that prompts the user to enter base and height of the triangle and calculate an area of this triangle (area = 0.5 x b x h).
b = float(input("Enter base: "))
h = float(input("Enter height: "))
area = 0.5 * b * h
print(f"Area of the triangle is:{area}")

#2.Write a script that prompts the user to enter side a, side b, and side c of the triangle. Calculate the perimeter, area of the triangle (perimeter = a + b + c).
a = float(input("Enter side a: "))
b = float(input("Enter side b: "))
c = float(input("Enter side c: "))
perimeter = a + b + c
# Note: To calculate the area of a triangle given three sides, you typically use Heron's formula.
# This was not requested in the prompt, so we will skip it for now.
print(f"Perimeter of the triangle is: { perimeter}")

#3.Get length and width of a rectangle using prompt. Calculate its area (area = length x width) and perimeter (perimeter = 2 x (length + width))
length = float(input("Enter length: "))
width = float(input("Enter width: "))
area = length * width
perimeter = 2 * (length + width)
print(f"Area of the rectangle is: {area}")
print(f"Perimeter of the rectangle is: {perimeter}")

#4.Get radius of a circle using prompt. Calculate the area (area = pi x r x r) and circumference (c = 2 x pi x r) where pi = 3.14.
radius = float(input("Enter radius: "))
pi = 3.14
area = pi * pow(radius, 2)
circumference = 2 * pi * radius
print(f"Area of the circle is: {area}")
print(f"Circumference of the circle is: {circumference}")

#5. Calculate the slope, x-intercept and y-intercept of y = 2x -2
# The equation y = 2x - 2 is in the form y = mx + c, where m is the slope and c is the y-intercept.
slope_eq5 = 2
y_intercept_eq5 = -2
# To find the x-intercept, set y to 0 and solve for x: 0 = 2x - 2 => 2x = 2 => x = 1
x_intercept_eq5 = 1
print("\nFor y = 2x - 2:")
print(f"Slope is: {slope_eq5}")
print(f"x-intercept is: {x_intercept_eq5}")
print(f"y-intercept is: {y_intercept_eq5}")

#6.Slope is (m = y2-y1/x2-x1). Find the slope and Euclidean distance between point (2, 2) and point (6,10)
x_1 = int(2)
y_1 = int(2)
x_2 = int(6)
y_2 = int(10)
slope_eq6 = (y_2 - y_1) / (x_2 - x_1)
print("\nFor (2, 2) and (6, 10):")
print(f"Slope is: {slope_eq6}")

#7.Calculate the value of y (y = x^2 + 6x + 9). Try to use different x values and figure out at what x value y is going to be 0.
x = float(input("Enter x: "))
y = pow(x, 2) + 6 * x + 9
print("\nFor x = {x}", "y = {y}")

x = int(0)
y = pow(x, 2) + 6 * x + 9
print(f"For x = ={x}", "y = {y}")

#8.Compare the slopes in tasks 5 and 6.
if slope_eq5 == slope_eq6:
    print("\nThe slopes are equal.")
else:
    print("The slopes are not equal.")

#9.Find the length of 'python' and 'dragon' and make a falsy comparison statement
len_python = len('python')
len_dragon = len('dragon')
falsy_comparison = len_python > len_dragon # This will be False as len('python') is 6 and len('dragon') is 6
print(f"\nLength of 'python' is: {len_python}")
print(f"Length of 'dragon' is: {len_dragon}")
print("Falsy comparison (length of 'python' > length of 'dragon'):", falsy_comparison)


#10.Use and operator to check if 'on' is found in both 'python' and 'dragon’
check_on_1 = 'on' in 'python' and 'on' in 'dragon'
print(f"\nIs 'on' found in both 'python' and 'dragon'?", check_on_1)

#11. “I hope this course is not full of jargon.” Use in operator to check if jargon is in the sentence.
check_on_2 = 'jargon'in 'I hope this course is not full of jargon.'
print(f"\nIs 'jargon' found in 'I hope this course is not full of jargon.'?", check_on_2)

#12. -

#13. Find the length of the text python and convert the value to float and convert it to string
text = str("python")
length = len(text)
float_value = float(length)
string_value = str(float_value)
print(f"\nLength of 'python' as a string is: {length}")
print(f"The integer value converted to float is: {float_value}")
print(f"The float value converted to a string is: {string_value}")

#14. Even numbers are divisible by 2 and the remainder is zero. How do you check if a number is even or not using python?
even_number = (int(input("Enter a number: ")) % 2 == 0)
print("\nIs the number even?", even_number)

#15.Writs a script that prompts the user to enter hours and rate per hour. Calculate pay of the person?
hours = float(input("Enter hours: "))
rate_per_hours = float(input("Enter rate per hour: "))
pay_of_the_person = hours * rate_per_hours
print(f"\nPay of the person is: {pay_of_the_person}")

#16. Write a script that prompts the user to enter number of years. Calculate the number of seconds a person can live. Assume a person can live hundred years
years = int(input("Enter number of years: "))
if years > 100:
    print("Please enter a number of years less than or equal to 100.")
if years <= 100:
    seconds = years * 365 * 24 * 60 * 60
print(f"\nNumber of seconds a person can live is: {seconds}")
# Out:
# Enter base: 4
# Enter height: 5
# Area of the triangle is:10.0
# Enter side a: 6
# Enter side b: 3
# Enter side c: 4
# Perimeter of the triangle is: 13.0
# Enter length: 5
# Enter width: 7
# Area of the rectangle is: 35.0
# Perimeter of the rectangle is: 24.0
# Enter radius: 3
# Area of the circle is: 28.26
# Circumference of the circle is: 18.84
#
# For y = 2x - 2:
# Slope is: 2
# x-intercept is: 1
# y-intercept is: -2
#
# For (2, 2) and (6, 10):
# Slope is: 2.0
# Enter x: 2
#
# For x = {x} y = {y}
# For x = =0 y = {y}
#
# The slopes are equal.
#
# Length of 'python' is: 6
# Length of 'dragon' is: 6
# Falsy comparison (length of 'python' > length of 'dragon'): False
#
# Is 'on' found in both 'python' and 'dragon'? True
#
# Is 'jargon' found in 'I hope this course is not full of jargon.'? True
#
# Length of 'python' as a string is: 6
# The integer value converted to float is: 6.0
# The float value converted to a string is: 6.0
# Enter a number: 4
#
# Is the number even? True
# ...
