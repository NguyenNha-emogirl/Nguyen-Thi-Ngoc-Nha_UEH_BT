# %%
#1. Write a Python program to calculate the length of a string.
a = "Hello world!"
print(len(a))

#2. Write a Python program to count the number of characters (character frequency) in a string.
#Sample String : google.com'
#Expected Result : {'g': 2, 'o': 3, 'l': 1, 'e': 1, '.': 1, 'c': 1, 'm': 1}
b = "google.com" # Added quotes around the string
for char in b:
  print(char, b.count(char))

#3. Write a Python program to get a string made of the first 2 and last 2 characters of a given string. If the string length is less than 2, return the empty string instead.
#Sample String : 'w3resource'
#Expected Result : 'w3ce'
#Sample String : 'w3'
#Expected Result : 'w3w3'
#Sample String : ' w'
#Expected Result : Empty String

c_1 = "w3resource"
if len(c_1) < 2:
  print("")
else:
  print(c_1[:2] + c_1[-2:])

c_2 = "w3"
if len(c_2) < 2:
  print("")
else:
  print(c_2[:2] + c_2[-2:])

c_3 = "w"
if len(c_3) < 2:
  print("")
else:
  print(c_3[:2] + c_3[-2:])

#4. Write a Python program to get a string from a given string where all occurrences of its first char have been changed to '$', except the first char itself.
#Sample String : 'restart'
#Expected Result : 'resta$t'
d = "restart"
if not "restart":
  print("")
first_char = d[0]
modified_string = first_char + d[1:].replace(first_char, "$")
print(modified_string)

#5. Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.
#Sample String : 'abc', 'xyz'
#Expected Result : 'xyc abz'
e_1 = "abc"
e_2 = "xyz"
if not "abc" and "xyz":
  print("")
new_e_1 = e_2[:2] + e_1[2:]
new_e_2 = e_1[:2] + e_2[2:]
print(f"Expected Result: {new_e_1} {new_e_2}")

#6. Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing', add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.
#Sample String : 'abc'
#Expected Result : 'abcing'
#Sample String : 'string'
#Expected Result : 'stringly'

f_1 = "abc"
if len(f_1) < 3:
  print(f_1)
if f_1.endswith("ing"):
  print(f_1 + "ly")
else:
  print(f_1 + "ing")

f_2 = "string"
if len(f_2) < 3:
  print(f_2)
if f_2.endswith("ing"):
  print(f_2 + "ly")
else:
  print(f_2 + "ing")

#7. Write a Python program to find the first appearance of the substrings 'not' and 'poor' in a given string. If 'not' follows 'poor', replace the whole 'not'...'poor' substring with 'good'. Return the resulting string.
#Sample String : 'The lyrics is not that poor!'
#'The lyrics is poor!'
#Expected Result : 'The lyrics is good!'
#'The lyrics is poor!'
g_1 = "The lyrics is not that poor!"
g_2 = "The lyrics is poor!"
if "not" and "poor" in g_1 and g_2:
  print(g_1 and g_2.replace("not that poor", "good"))
# Out:
# 12
# g 2
# o 3
# o 3
# g 2
# l 1
# e 1
# . 1
# c 1
# o 3
# m 1
# w3ce
# w3w3
#
# resta$t
# Expected Result: xyc abz
# abcing
# stringly
# The lyrics is poor!
